# %%
import json

# Load the JSON annotation file
with open('/kaggle/input/chula-parasite-dataset/Chula-ParasiteEgg-11/Chula-ParasiteEgg-11/Chula-ParasiteEgg-11/labels.json', 'r') as json_file:
    data = json.load(json_file)
    
# Extract relevant information from the JSON data
images = data['images']
annotations = data['annotations']
categories = data['categories']

print(categories)
